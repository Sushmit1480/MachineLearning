# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushmit1480/MachineLearning/blob/main/ML_Practical3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c017a4fd-bbc6-4408-9ded-251902c72a29" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c017a4fd-bbc6-4408-9ded-251902c72a29">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving demo.csv to demo.csv

# %% [markdown]
# # Read Data

# %%
import pandas as pd
import io

df  = pd.read_csv(io.BytesIO(uploaded['demo.csv']))

# %% [markdown]
# # Print Head Values

# %%
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  ...  BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0  83732     1.0     NaN     1.0  ...     43.6     35.9     101.1     2.0
# 1  83733     1.0     NaN     6.0  ...     40.0     33.2     107.9     NaN
# 2  83734     1.0     NaN     NaN  ...     37.0     31.0     116.5     2.0
# 3  83735     2.0     1.0     1.0  ...     37.7     38.3     110.1     2.0
# 4  83736     2.0     1.0     1.0  ...     36.0     27.2      80.4     2.0
#
# [5 rows x 28 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Bar Chart

# %%
sns.distplot(df.INDFMPIR.dropna())
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.BPXSY1.dropna())
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Point Plot

# %%
sns.pointplot(x="agegrp", y="BPXSY1", hue="RIAGENDR",data=df, color_palette={"male":"1","female":"2"},markers=["^","o"],linestyles=["-","--"])

# %% [markdown]
# # Box Plot

# %%
bp = sns.boxplot(data=df.loc[:, ["BPXSY1", "BPXSY2", "BPXDI1", "BPXDI2"]])
_ = bp.set_ylabel("Blood pressure in mm/Hg")

# %%
df["agegrp"] = pd.cut(df.RIDAGEYR, [18, 30, 40, 50, 60, 70, 80]) # Create age strata based on these cut points
plt.figure(figsize=(12, 5))  # Make the figure wider than default (12cm wide by 5cm tall)
sns.boxplot(x="agegrp", y="BPXSY1", data=df)  # Make boxplot of BPXSY1 stratified by age group

# %%
df["agegrp"] = pd.cut(df.RIDAGEYR, [18, 30, 40, 50, 60, 70, 80])
plt.figure(figsize=(12, 5))
sns.boxplot(x="agegrp", y="BPXSY1", hue="RIAGENDR", data=df)

# %%
df["agegrp"] = pd.cut(df.RIDAGEYR, [18, 30, 40, 50, 60, 70, 80])
plt.figure(figsize=(12, 5))
sns.boxplot(x="RIAGENDR", y="BPXSY1", hue="agegrp", data=df)

# %% [markdown]
# # Violin plot

# %%
sns.violinplot(x="RIAGENDR", y="BPXSY1", hue="agegrp", data=df)
